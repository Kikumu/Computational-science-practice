# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import csv
#"step" function by robot

#def func(x,U):
    #-2x+2U
    #val = -(2*x)+2*U
    #return val

#different order of parameters passed different behaviour??????
def func(U,x):
    #-2x+2U
    val = -(2*x) + 2*U
    return val

# %%
a = 0
b = 0

t = a
x = b
#h =1 #step size
h = 0.321
U_array = []
t_array = []
x_array = []
x_exact_array = []
while(t <= 15):
    if(t <= 5):
      U = 2
    elif(t < 5 <= 10):
      U = 1
    elif(10 < t <= 15):
      U = 3
    print("U value:", x)
    U_array.append(U)
    k = h * func(U,x)
    x = x + k
    t = t + h
    #value under graph
    x_exact = U - math.exp(-2*t)
    t_array.append(t)
    x_array.append(x)
    x_exact_array.append(x_exact)
    print("Where it is: ",x,"Exact pos= ",x_exact,"Time: ",t)
    #plt.fill_between(x_axis,y_axis, where = [(x>0)and (x <2)for x_axis in x_axis], color = 'green')
# Out:
# U value: 0
# Where it is:  1.284 Exact pos=  1.4737611069228946 Time:  0.321
# U value: 1.284
# Where it is:  1.743672 Exact pos=  1.7230726274129828 Time:  0.642
# U value: 1.743672
# Where it is:  1.9082345760000001 Exact pos=  1.854270045987057 Time:  0.9630000000000001
# U value: 1.9082345760000001
# Where it is:  1.9671479782080001 Exact pos=  1.9233112303120514 Time:  1.284
# U value: 1.9671479782080001
# Where it is:  1.988238976198464 Exact pos=  1.9596433867279688 Time:  1.605
# U value: 1.988238976198464
# Where it is:  1.9957895534790502 Exact pos=  1.9787627805033856 Time:  1.926
# U value: 1.9957895534790502
# Where it is:  1.9984926601455 Exact pos=  1.988824149120066 Time:  2.247
# U value: 1.9984926601455
# Where it is:  1.999460372332089 Exact pos=  1.9941188326037487 Time:  2.568
# U value: 1.999460372332089
# Where it is:  1.9998068132948879 Exact pos=  1.9969051009793957 Time:  2.8890000000000002
# U value: 1.9998068132948879
# Where it is:  1.9999308391595698 Exact pos=  1.9983713437652117 Time:  3.2100000000000004
# U value: 1.9999308391595698
# Where it is:  1.999975240419126 Exact pos=  1.9991429377458019 Time:  3.5310000000000006
# U value: 1.999975240419126
# Where it is:  1.999991136070047 Exact pos=  1.9995489805080526 Time:  3.8520000000000008
# U value: 1.999991136070047
# Where it is:  1.9999968267130768 Exact pos=  1.9997626560018014 Time:  4.173000000000001
# U value: 1.9999968267130768
# Where it is:  1.9999988639632815 Exact pos=  1.9998751003571096 Time:  4.494000000000001
# U value: 1.9999988639632815
# Where it is:  1.9999995932988548 Exact pos=  1.9999342729501797 Time:  4.815
# U value: 1.9999995932988548
# Where it is:  1.99999985440099 Exact pos=  1.9999654118700572 Time:  5.136
# U value: 1.99999985440099
# Where it is:  1.9999999478755544 Exact pos=  1.9999817983807853 Time:  5.457
# U value: 1.9999999478755544
# Where it is:  1.9999999813394485 Exact pos=  1.9999904216000524 Time:  5.778
# U value: 1.9999999813394485
# Where it is:  1.9999999933195225 Exact pos=  1.999994959473414 Time:  6.098999999999999
# U value: 1.9999999933195225
# Where it is:  1.999999997608389 Exact pos=  1.9999973474788688 Time:  6.419999999999999
# U value: 1.999999997608389
# Where it is:  1.9999999991438033 Exact pos=  1.999998604140216 Time:  6.740999999999999
# U value: 1.9999999991438033
# Where it is:  1.9999999996934816 Exact pos=  1.9999992654442924 Time:  7.0619999999999985
# U value: 1.9999999996934816
# Where it is:  1.9999999998902664 Exact pos=  1.9999996134482176 Time:  7.382999999999998
# U value: 1.9999999998902664
# Where it is:  1.9999999999607154 Exact pos=  1.9999997965814178 Time:  7.703999999999998
# U value: 1.9999999999607154
# Where it is:  1.9999999999859361 Exact pos=  1.9999998929532306 Time:  8.024999999999999
# U value: 1.9999999999859361
# Where it is:  1.9999999999949651 Exact pos=  1.9999999436678266 Time:  8.345999999999998
# U value: 1.9999999999949651
# Where it is:  1.9999999999981974 Exact pos=  1.9999999703558193 Time:  8.666999999999998
# U value: 1.9999999999981974
# Where it is:  1.9999999999993547 Exact pos=  1.9999999844000793 Time:  8.987999999999998
# U value: 1.9999999999993547
# Where it is:  1.999999999999769 Exact pos=  1.999999991790715 Time:  9.308999999999997
# U value: 1.999999999999769
# Where it is:  1.9999999999999174 Exact pos=  1.999999995679955 Time:  9.629999999999997
# U value: 1.9999999999999174
# Where it is:  1.9999999999999705 Exact pos=  1.9999999977266243 Time:  9.950999999999997
# U value: 1.9999999999999705
# Where it is:  1.9999999999999893 Exact pos=  1.9999999988036612 Time:  10.271999999999997
# U value: 1.9999999999999893
# Where it is:  2.6419999999999964 Exact pos=  2.99999999937044 Time:  10.592999999999996
# U value: 2.6419999999999964
# Where it is:  2.8718359999999987 Exact pos=  2.999999999668701 Time:  10.913999999999996
# U value: 2.8718359999999987
# Where it is:  2.9541172879999995 Exact pos=  2.9999999998256577 Time:  11.234999999999996
# U value: 2.9541172879999995
# Where it is:  2.983573989104 Exact pos=  2.9999999999082543 Time:  11.555999999999996
# U value: 2.983573989104
# Where it is:  2.994119488099232 Exact pos=  2.99999999995172 Time:  11.876999999999995
# U value: 2.994119488099232
# Where it is:  2.997894776739525 Exact pos=  2.999999999974593 Time:  12.197999999999995
# U value: 2.997894776739525
# Where it is:  2.99924633007275 Exact pos=  2.99999999998663 Time:  12.518999999999995
# U value: 2.99924633007275
# Where it is:  2.9997301861660444 Exact pos=  2.9999999999929643 Time:  12.839999999999995
# U value: 2.9997301861660444
# Where it is:  2.999903406647444 Exact pos=  2.9999999999962976 Time:  13.160999999999994
# U value: 2.999903406647444
# Where it is:  2.999965419579785 Exact pos=  2.999999999998052 Time:  13.481999999999994
# U value: 2.999965419579785
# Where it is:  2.999987620209563 Exact pos=  2.9999999999989746 Time:  13.802999999999994
# U value: 2.999987620209563
# Where it is:  2.9999955680350237 Exact pos=  2.9999999999994604 Time:  14.123999999999993
# U value: 2.9999955680350237
# Where it is:  2.9999984133565385 Exact pos=  2.9999999999997162 Time:  14.444999999999993
# U value: 2.9999984133565385
# Where it is:  2.999999431981641 Exact pos=  2.999999999999851 Time:  14.765999999999993
# U value: 2.999999431981641
# Where it is:  2.9999997966494276 Exact pos=  2.9999999999999214 Time:  15.086999999999993

# %%
y_axis = x_exact_array
x_axis = t_array
plt.plot(x_axis,y_axis)
plt.fill_between(x_axis,y_axis, where = [(x>0)and (x <2)for x_axis in x_axis], color = 'green')
#plt.show()

# %%
y_axis = x_array
x_axis = t_array
plt.plot(x_axis,y_axis)
plt.show()

# %%
import sympy as sy

# %%
y_axis = U_array
x_axis = t_array
plt.plot(x_axis,y_axis)
plt.show()

# %%
y_axis = U_array
x_axis = x_array
plt.plot(x_axis,y_axis)
plt.show()

# %%
#DEVIATIONS AND MEAN

import statistics as stat
std_dev1 = stat.stdev(x_array)
#_mean = stat.mean(x_array)

std_dev = 0.291
_mean = 0.0
print("deviation: ",std_dev,"mean: ",_mean,std_dev1)
# Out:
# deviation:  0.291 mean:  0.0 0.4854578126253046

# %%
#time against x value
#important for box mulla: mean,standard deviation,time,x,and U
#mean and standard deviation is used to "limit" the box mulla
#BOX MULLA
#sigma = _mean
#meu = std_dev

##step 1
##iterations?....use time
import random as rand
import math

z1 = rand.uniform(0,2*np.pi) #values from 0 to (2*np.pi)#
b = _mean * np.sqrt(-2*math.log10(rand.uniform(0,1)))
z2 = b * math.sin(z1)+std_dev
z3 = b* math.cos(z1)+std_dev
noise = x + z1
print(noise,x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-5935407e716e> in <module>
#      15 z2 = b * math.sin(z1)+std_dev
#      16 z3 = b* math.cos(z1)+std_dev
# ---> 17 noise = x + z1
#      18 print(noise,x)
#
# TypeError: can only concatenate list (not "float") to list

# %%
print(len(t_array))
# Out:
# 47

# %%
#print(len(random_vals))

# %%
print(np.pi)
# Out:
# 3.141592653589793

# %%
random_vals = []
#random_vals[1,2,3,3]
i = 0
it = 0
while i < len(x_array):
 if(it==0):
    z1 = rand.uniform(0,2*np.pi) #values from 0 to (2*np.pi)#
    b = std_dev * np.sqrt(-2*math.log(rand.uniform(0,1)))
    z2 = b * math.sin(z1)+_mean
    z3 = b* math.cos(z1)+_mean
    noise = x_array[i] + z2
    print("nose1: ",noise,x_array[i])
    it = 1
    i = i + 1
    random_vals.append(noise) #dividenoise by 10 for "scaling" to step size?....
   # print("nose1: ",noise/10,x_exact_array[i])
 else:
    it = 0
    noise = x_array[i] + z3
    i = i + 1
    random_vals.append(noise)  
    print("nose2: ",noise,x_array[i])
        
#meu is mean sigma is std deviation
y_axis = x_array
x_axis = t_array
plt.xlabel("Time")
plt.ylabel("Distance")
#plt.plot(random_vals,color ="red")
plt.plot(x_axis,y_axis,)
plt.show()
# Out:
# nose1:  1.3813224548701724 1.284
# nose2:  1.6726608434171772 1.9082345760000001
# nose1:  1.9089333364750967 1.9082345760000001
# nose2:  2.361039083048739 1.988238976198464
# nose1:  1.6607163344170295 1.988238976198464
# nose2:  1.8135147448641211 1.9984926601455
# nose1:  2.3136227947066286 1.9984926601455
# nose2:  1.7824434548869057 1.9998068132948879
# nose1:  2.323757351459302 1.9998068132948879
# nose2:  2.1262460559833203 1.999975240419126
# nose1:  1.6338344948403845 1.999975240419126
# nose2:  1.9368965237747635 1.9999968267130768
# nose1:  1.8161755829129458 1.9999968267130768
# nose2:  1.9233385081234355 1.9999995932988548
# nose1:  2.021431847952002 1.9999995932988548
# nose2:  2.77200985086398 1.9999999478755544
# nose1:  1.6901818448534258 1.9999999478755544
# nose2:  2.391008781723013 1.9999999933195225
# nose1:  1.7223529003151101 1.9999999933195225
# nose2:  1.689632916328784 1.9999999991438033
# nose1:  2.277528042799545 1.9999999991438033
# nose2:  2.5267621713725195 1.9999999998902664
# nose1:  2.066518693884457 1.9999999998902664
# nose2:  2.218020548296242 1.9999999999859361
# nose1:  1.9937460894565113 1.9999999999859361
# nose2:  1.4931331369036518 1.9999999999981974
# nose1:  2.133473107799176 1.9999999999981974
# nose2:  2.1335196171590862 1.999999999999769
# nose1:  2.0682248916405883 1.999999999999769
# nose2:  2.0166522417051884 1.9999999999999705
# nose1:  2.0100084164047525 1.9999999999999705
# nose2:  1.8661539643774683 2.6419999999999964
# nose1:  2.935374301237202 2.6419999999999964
# nose2:  3.136334317998655 2.9541172879999995
# nose1:  3.245363552741743 2.9541172879999995
# nose2:  3.347002053044915 2.994119488099232
# nose1:  3.06044266675636 2.994119488099232
# nose2:  2.860752309924875 2.99924633007275
# nose1:  2.296507632009636 2.99924633007275
# nose2:  2.9995417938465687 2.999903406647444
# nose1:  2.9191966815814907 2.999903406647444
# nose2:  2.585451841228668 2.999987620209563
# nose1:  3.4996171070226803 2.999987620209563
# nose2:  3.2015453206157485 2.9999984133565385
# nose1:  2.7203901604940075 2.9999984133565385
# nose2:  3.0074926184879462 2.9999997966494276
# nose1:  3.2724549862160255 2.9999997966494276

# %%
#plt.figure()
#plt.plot(t_array)
y_axis = random_vals
y = x_array
x_axis = x = t_array
#x = t_array

plt.plot(x,y,"r")
plt.plot(x_axis,y_axis)
plt.show()
